# %% [markdown]
# # LetsUpgrade_Day8_Assignment1

# %% [markdown]
# # Q1.

# %%
def EnterName(inp):
    def reverse():
        centered_text = inp()
        return centered_text[::-1]
    return reverse

@EnterName
def reversename():
    text = input('Type the name:')
    return text

# %% [markdown]
# # Q2.

# %%
try:
    f = open("newtextfile.txt","r")
    f.write("Read only file")
except:
    print("This is read only file")
# Out:
# This is read only file
